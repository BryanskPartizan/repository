# %%
import csv
import matplotlib.pyplot as plt
import numpy as np


def writer(path, fieldnames, data):
    with open(path, 'w', newline='') as out_file:
        writer = csv.DictWriter(out_file, delimiter=';', fieldnames=fieldnames)
        writer.writeheader()
        for row in data:
            writer.writerow(row)
            
def data_creator(list_x, list_y, fieldnames):
    data = []
    result_data = []
    for index in range(len(list_x)):
        data.append([list_x[index], list_y[index]])
   
    for values in data:
        sub_dict = dict(zip(fieldnames, values))
        result_data.append(sub_dict)
    return result_data

z = f(x)
def reader(path):
    x_val = []
    y_val = []
    with open(path, 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file, delimiter=';')
        for line in reader:
            x_val.append(line['x'])
            y_val.append(line['y'])
    return x_val, y_val

f = lambda x: x**3 + 5*x - 4
x = np.arange(-10, 10, 0.01)
y = [f(x0) for x0 in x]
path = 'ex_3.csv'
    
fieldnames = ['x', 'y']
final_data = data_creator(x, y, fieldnames)
writer(path, fieldnames, final_data)

x_val = np.array(reader(path)[0])
y_val = np.array(reader(path)[1])

fig = plt.figure(figsize=(10, 10))

plt.plot(x_val, z, label='y = x^3 + 5x - 4', color='purple', linewidth=2)
plt.xticks([-10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10],
          ['-10', '-8', '-6', '-4', '-2', '0', '2', '4', '6', '8', '10'])
plt.title('function: y = x^3 + 5x - 4')
plt.legend(loc='upper left')
